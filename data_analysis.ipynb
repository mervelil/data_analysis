# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sample=pd.read_csv('/content/SampleSuperstore.csv', encoding='latin1')
sample.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
sample.shape
# Out:
# (9994, 21)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# **Checking No. of Null values in the dataset**

# %%
sample.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
sample.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# Checking No. of Duplicate values in the dataset

# %%
sample.duplicated().sum()
# Out:
# 0

# %%
sample.drop_duplicates()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# Plot depicting the Shipment Count across various Ship Modes

# %%
plt.figure(figsize=(9,5))
plt.style.use('bmh')
sns.countplot(x='Ship Mode',data=sample)
plt.ylabel('No. of Shipments')
# Out:
# Text(0, 0.5, 'No. of Shipments')

# %% [markdown]
# **Standard Class was the most preferred Shipment Mode and Same Day was the least preferred option.**

# %% [markdown]
# Dropping all the Unnecessary Columns

# %%
sample.drop(['Postal Code'],axis=1,inplace=True)

# %%
sample.drop([ 'Ship Mode'],axis=1,inplace=True)
sample.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# Plotting Pairwise relationship b/w columns

# %%
sns.pairplot(data=sample, hue='Category')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_cols = sample.select_dtypes(include='number')

# Calculate the correlation matrix
samp_heat = numeric_cols.corr()

# Plot the heatmap
sns.heatmap(samp_heat, annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# Least Correlated: Discount and Quantity
# Most Correlated : Profit and Sales

# %%
print("The TOTAL SALES in the dataset is {}".format(sample["Sales"].sum()))
print("The TOTAL PROFIT in the dataset is {}".format(sample["Profit"].sum()))
# Out:
# The TOTAL SALES in the dataset is 2297200.8603000003
# The TOTAL PROFIT in the dataset is 286397.0217

# %% [markdown]
# Graph showing Sales across different Categories

# %%
plt.figure(figsize=(9,5))
plt.bar(sample['Category'],sample['Sales'])
plt.xlabel('Cateories')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Count of Segment by Category and Segment

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='Category',hue='Segment',data=sample)
plt.ylabel('Count of Segment')
plt.title('Count of Segment by Category and Segment')
# Out:
# Text(0.5, 1.0, 'Count of Segment by Category and Segment')

# %% [markdown]
# JointPlot depicting Sales across Regions

# %%
sns.jointplot(x='Region', y='Sales', data=sample)

# %% [markdown]
# CountPlot depicting the No. of Sub-Categories

# %%
plt.figure(figsize=(16,9))
sns.countplot(sample['Sub-Category'], palette='dark')

plt.title('Count of Sub-Category', fontsize=15)
# Out:
# <ipython-input-24-58cd596da393>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(sample['Sub-Category'], palette='dark')
# Text(0.5, 1.0, 'Count of Sub-Category')

# %% [markdown]
# LinePlot depicting relation b/w Discount and Profit

# %%
sns.lineplot(y="Profit", x="Discount",data=sample,color='red')
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# Analysing the Total Sales, Profit, Discount of all the Sub-Categories

# %%
sample_subcategory=sample.groupby(['Sub-Category'])[['Sales', 'Profit', 'Discount']].sum()
sample_subcategory.head(18)
# Out:
#                     Sales      Profit  Discount
# Sub-Category
# Accessories   167380.3180  41936.6357     60.80
# Appliances    107532.1610  18138.0054     77.60
# Art            27118.7920   6527.7870     59.60
# Binders       203412.7330  30221.7633    567.00
# Bookcases     114879.9963  -3472.5560     48.14
# Chairs        328449.1030  26590.1663    105.00
# Copiers       149528.0300  55617.8249     11.00
# Envelopes      16476.4020   6964.1767     20.40
# Fasteners       3024.2800    949.5182     17.80
# Furnishings    91705.1640  13059.1436    132.40
# Labels         12486.3120   5546.2540     25.00
# Machines      189238.6310   3384.7569     35.20
# Paper          78479.2060  34053.5693    102.60
# Phones        330007.0540  44515.7306    137.40
# Storage       223843.6080  21278.8264     63.20
# Supplies       46673.5380  -1189.0995     14.60
# Tables        206965.5320 -17725.4811     83.35

# %%
# @title Discount

from matplotlib import pyplot as plt
sample_subcategory['Discount'].plot(kind='line', figsize=(8, 4), title='Discount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Phones had the highest sales among all Sub-Categories followed by Chairs, Storage, Tables, etc. Copiers made the highest profit. Bookcases made the least profit but made good Sales. The cost of Bookcases can be increased to increase the profit.

# %% [markdown]
# **PieChart depicting distribiution of Segment**

# %%
seg=sample["Segment"].value_counts()
seg
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
seg.plot(kind="pie", figsize=(5,5),autopct='%1.1f%%',fontsize=13, shadow=True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Consumer segment has highest share followed by Corporate and Home Office.

# %% [markdown]
# Segment-wise Profit & Sales

# %%
plt.style.use('seaborn-dark')
seg_salesNprofit=sample.groupby("Segment")[["Sales", "Profit"]].sum()
seg_salesNprofit.plot(kind="bar", figsize=(8,5))
plt.ylabel("Sales & Profit")
plt.title("Segment: Profit & Sales", fontsize=15)
# Out:
# <ipython-input-30-b8b386c0cf77>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')
# Text(0.5, 1.0, 'Segment: Profit & Sales')

# %%
#state wise
state_count=sample["State"].value_counts()
state_count
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
#State-wise Distribution of Consumer
plt.style.use('seaborn-bright')
state_count.plot(kind="bar", figsize=(15,8))
plt.xlabel("States")
plt.ylabel("No. of Consumers")
plt.title("Distribution of Consumers in each State")
# Out:
# <ipython-input-32-04a0bff194c6>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-bright')
# Text(0.5, 1.0, 'Distribution of Consumers in each State')

# %% [markdown]
#  **Summing up the Sales across various Categories**

# %%
category_sales_sum=sample.groupby("Category").Sales.sum()
category_sales_sum
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
label=['Furniture','Office Supplies','Technology']
plt.style.use('fivethirtyeight')
category_sales_sum.plot(kind="pie", figsize=(7,7),labels=label,autopct='%1.1f%%',fontsize=13, shadow=True)
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Pie-Chart depicting the proportion of Sales across the 3 Categories
# Technology has the highest Sales followed by Furniture and Office Supplies. Also, all the Categories contribute nearly the same amount towards total sales.

# %% [markdown]
# Profit & Sales across various Categories

# %%
import matplotlib.pyplot as plt


category_sales_profit = sample.groupby('Category')[['Sales', 'Profit']].agg(sum)


category_sales_profit.plot(kind='bar')


plt.style.use('seaborn-colorblind')

plt.ylabel('Profit & Sales')
plt.show()
#Furniture is making the least profit among the 3 categories
# Out:
# <ipython-input-36-b31777e4cc81>:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-colorblind')

# %% [markdown]
# Summing up the Profit across different Regions

# %%
region_profit_sum=sample.groupby("Region").Profit.sum()
region_profit_sum
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
plt.style.use('bmh')
standout=[0,0,0,0.1]
plt2=region_profit_sum.plot(kind="pie",explode=standout, figsize=(7,7),autopct='%1.1f%%',fontsize=12, shadow=True)

# %% [markdown]
# The West region made the highest Profit, followed by East, South and Central Region.
# Summary
# • Area with Highest Sales & Profit: Technology, West, Consumer
# • Area with Lowest Sales & Profit: Furniture, Central, Home Office
# • California and New York have the highest number of Consumers
# • Phones had the highest sales among all Sub-Categories followed by Chairs, Storage, Tables, etc. Copiers made the highest profit. Bookcases made the least profit but made good Sales. The cost of Bookcases can be increased to increase the profit.
# • Standard Class was the most preferred Shipment Mode
